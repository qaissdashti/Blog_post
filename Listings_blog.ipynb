# %%
# get all the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# <h2> Lets feel the data frame</h2>
#
# load the data

# %%
listing_df = pd.read_csv('C:/Users/GIGABYTE/Desktop/blog_post/listings.csv')

# %%
listing_df.head()
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1   953595   https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 2  3308979  https://www.airbnb.com/rooms/3308979  20160104002432   2016-01-04
# 3  7421966  https://www.airbnb.com/rooms/7421966  20160104002432   2016-01-04
# 4   278830   https://www.airbnb.com/rooms/278830  20160104002432   2016-01-04
#
#                                   name  \
# 0         Stylish Queen Anne Apartment
# 1   Bright & Airy Queen Anne Apartment
# 2  New Modern House-Amazing water view
# 3                   Queen Anne Chateau
# 4       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# ...

# %%
listing_df.shape
# Out:
# (3818, 92)

# %%
listing_df.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  3.818000e+03  3.818000e+03  3.818000e+03          3816.000000
# mean   5.550111e+06  2.016010e+13  1.578556e+07             7.157757
# std    2.962660e+06  0.000000e+00  1.458382e+07            28.628149
# min    3.335000e+03  2.016010e+13  4.193000e+03             1.000000
# 25%    3.258256e+06  2.016010e+13  3.275204e+06             1.000000
# 50%    6.118244e+06  2.016010e+13  1.055814e+07             1.000000
# 75%    8.035127e+06  2.016010e+13  2.590309e+07             3.000000
# max    1.034016e+07  2.016010e+13  5.320861e+07           502.000000
#
#        host_total_listings_count     latitude    longitude  accommodates  \
# count                3816.000000  3818.000000  3818.000000   3818.000000
# mean                    7.157757    47.628961  -122.333103      3.349398
# std                    28.628149     0.043052     0.031745      1.977599
# ...

# %%
listing_df.dtypes
# Out:
# id                                    int64
# listing_url                          object
# scrape_id                             int64
# last_scraped                         object
# name                                 object
# summary                              object
# space                                object
# description                          object
# experiences_offered                  object
# neighborhood_overview                object
# notes                                object
# transit                              object
# thumbnail_url                        object
# medium_url                           object
# picture_url                          object
# xl_picture_url                       object
# host_id                               int64
# host_url                             object
# host_name                            object
# host_since                           object
# host_location                        object
# ...

# %%
list_num = listing_df.select_dtypes(exclude='object').columns

# %%
#to display more rows to better understand the data
pd.set_option('display.max_columns', 500)

# %%
list_num
# Out:
# Index(['id', 'scrape_id', 'host_id', 'host_listings_count',
#        'host_total_listings_count', 'latitude', 'longitude', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'square_feet', 'guests_included',
#        'minimum_nights', 'maximum_nights', 'availability_30',
#        'availability_60', 'availability_90', 'availability_365',
#        'number_of_reviews', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'calculated_host_listings_count',
#        'reviews_per_month'],
#       dtype='object')

# %%
listing_df.shape
# Out:
# (3818, 92)

# %% [markdown]
# <h2> Analyse which column to remove with out any fill

# %% [markdown]
# Looking at the percentages of null values to better evaluate what features to deleter or impute

# %%
#nan by percentage to see what to remove
listing_df[list_num].isnull().sum() / listing_df.shape[0]
# Out:
# id                                0.000000
# scrape_id                         0.000000
# host_id                           0.000000
# host_listings_count               0.000524
# host_total_listings_count         0.000524
# latitude                          0.000000
# longitude                         0.000000
# accommodates                      0.000000
# bathrooms                         0.004191
# bedrooms                          0.001572
# beds                              0.000262
# square_feet                       0.974594
# guests_included                   0.000000
# minimum_nights                    0.000000
# maximum_nights                    0.000000
# availability_30                   0.000000
# availability_60                   0.000000
# availability_90                   0.000000
# availability_365                  0.000000
# number_of_reviews                 0.000000
# review_scores_rating              0.169460
# review_scores_accuracy            0.172342
# ...

# %% [markdown]
# <h2> Wrangle the numeric part of the data frame </h2>

# %%
# Now we have all the numeric values in a seperate DF, but we are still missing cols
# that are strings but can be converted to numerical.
numeric_df = listing_df[list_num]

# %%
numeric_df.head()
# Out:
#         id       scrape_id   host_id  host_listings_count  \
# 0   241032  20160104002432    956883                  3.0
# 1   953595  20160104002432   5177328                  6.0
# 2  3308979  20160104002432  16708587                  2.0
# 3  7421966  20160104002432   9851441                  1.0
# 4   278830  20160104002432   1452570                  2.0
#
#    host_total_listings_count   latitude   longitude  accommodates  bathrooms  \
# 0                        3.0  47.636289 -122.371025             4        1.0
# 1                        6.0  47.639123 -122.365666             4        1.0
# 2                        2.0  47.629724 -122.369483            11        4.5
# 3                        1.0  47.638473 -122.369279             3        1.0
# 4                        2.0  47.632918 -122.372471             6        2.0
#
#    bedrooms  beds  square_feet  guests_included  minimum_nights  \
# 0       1.0   1.0          NaN                2               1
# ...

# %%
numeric_df.shape
# Out:
# (3818, 30)

# %%
#droped the license col, its all nans
numeric_df.dropna(how='all', axis=1, inplace=True)
# Out:
# C:\Users\GIGABYTE\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
numeric_df.shape
# Out:
# (3818, 29)

# %%
#drop sqaure feet , has 97% nans
numeric_df.drop('square_feet', axis=1, inplace=True)
# Out:
# C:\Users\GIGABYTE\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
numeric_df.shape
# Out:
# (3818, 28)

# %% [markdown]
# For now will continue working with what i have as NaN, if i face any troubles then will start imputing

# %%
#the test can be imputed or filled later with means or frequeant 
numeric_df.isnull().sum() / numeric_df.shape[0]
# Out:
# id                                0.000000
# scrape_id                         0.000000
# host_id                           0.000000
# host_listings_count               0.000524
# host_total_listings_count         0.000524
# latitude                          0.000000
# longitude                         0.000000
# accommodates                      0.000000
# bathrooms                         0.004191
# bedrooms                          0.001572
# beds                              0.000262
# guests_included                   0.000000
# minimum_nights                    0.000000
# maximum_nights                    0.000000
# availability_30                   0.000000
# availability_60                   0.000000
# availability_90                   0.000000
# availability_365                  0.000000
# number_of_reviews                 0.000000
# review_scores_rating              0.169460
# review_scores_accuracy            0.172342
# review_scores_cleanliness         0.171032
# ...

# %%
numeric_df.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  3.818000e+03  3.818000e+03  3.818000e+03          3816.000000
# mean   5.550111e+06  2.016010e+13  1.578556e+07             7.157757
# std    2.962660e+06  0.000000e+00  1.458382e+07            28.628149
# min    3.335000e+03  2.016010e+13  4.193000e+03             1.000000
# 25%    3.258256e+06  2.016010e+13  3.275204e+06             1.000000
# 50%    6.118244e+06  2.016010e+13  1.055814e+07             1.000000
# 75%    8.035127e+06  2.016010e+13  2.590309e+07             3.000000
# max    1.034016e+07  2.016010e+13  5.320861e+07           502.000000
#
#        host_total_listings_count     latitude    longitude  accommodates  \
# count                3816.000000  3818.000000  3818.000000   3818.000000
# mean                    7.157757    47.628961  -122.333103      3.349398
# std                    28.628149     0.043052     0.031745      1.977599
# ...

# %%
numeric_df.id.head()
# Out:
# 0     241032
# 1     953595
# 2    3308979
# 3    7421966
# 4     278830
# Name: id, dtype: int64

# %%
#checking that IDs are unique
len(numeric_df.id.unique())
# Out:
# 3818

# %%
numeric_df.host_listings_count.plot()

# %%
numeric_df.host_listings_count.head()
# Out:
# 0    3.0
# 1    6.0
# 2    2.0
# 3    1.0
# 4    2.0
# Name: host_listings_count, dtype: float64

# %% [markdown]
# To check for any string cols that can be changed to numeric

# %%
listing_df.head(2)
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0  241032  https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1  953595  https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
#
#                                  name  \
# 0        Stylish Queen Anne Apartment
# 1  Bright & Airy Queen Anne Apartment
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
#
#                                                space  \
# 0  Make your self at home in this charming one-be...
# 1  Beautiful, hypoallergenic apartment in an extr...
#
#                                          description experiences_offered  \
# 0  Make your self at home in this charming one-be...                none
# 1  Chemically sensitive? We've removed the irrita...                none
#
#                                neighborhood_overview  \
# ...

# %% [markdown]
# <b> Change some of the object type cols into Numeric</b>

# %%
#these col can be changed to numeric col
to_change_numeric = ['price', 'weekly_price', 'monthly_price', 'security_deposit', 'cleaning_fee', 'extra_people']

# %%
to_change_numeric
# Out:
# ['price',
#  'weekly_price',
#  'monthly_price',
#  'security_deposit',
#  'cleaning_fee',
#  'extra_people']

# %%
# they are objects can be changed to numeric
for col in to_change_numeric:
    print(listing_df[col].dtype)
# Out:
# object
# object
# object
# object
# object
# object

# %%
#As we can see there are NaNs and string charachters like $
fixed_num = listing_df[to_change_numeric]
fixed_num.head()
# Out:
#      price weekly_price monthly_price security_deposit cleaning_fee  \
# 0   $85.00          NaN           NaN              NaN          NaN
# 1  $150.00    $1,000.00     $3,000.00          $100.00       $40.00
# 2  $975.00          NaN           NaN        $1,000.00      $300.00
# 3  $100.00      $650.00     $2,300.00              NaN          NaN
# 4  $450.00          NaN           NaN          $700.00      $125.00
#
#   extra_people
# 0        $5.00
# 1        $0.00
# 2       $25.00
# 3        $0.00
# 4       $15.00

# %%
# we use the below loop to remove the $ from the cols

for col in fixed_num.columns:
    fixed_num[col].replace({'\$':''}, regex=True, inplace=True)
# Out:
# C:\Users\GIGABYTE\Anaconda3\lib\site-packages\pandas\core\generic.py:5890: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %% [markdown]
# Now we can see that we removed the $ from the DataFrame

# %%
fixed_num.head()
# Out:
#     price weekly_price monthly_price security_deposit cleaning_fee  \
# 0   85.00          NaN           NaN              NaN          NaN
# 1  150.00     1,000.00      3,000.00           100.00        40.00
# 2  975.00          NaN           NaN         1,000.00       300.00
# 3  100.00       650.00      2,300.00              NaN          NaN
# 4  450.00          NaN           NaN           700.00       125.00
#
#   extra_people
# 0         5.00
# 1         0.00
# 2        25.00
# 3         0.00
# 4        15.00

# %%
fixed_num.dtypes
# Out:
# price               object
# weekly_price        object
# monthly_price       object
# security_deposit    object
# cleaning_fee        object
# extra_people        object
# dtype: object

# %%
#changing the types to floats
for col in fixed_num.columns:
    fixed_num[col] = pd.to_numeric(fixed_num[col], errors='coerce')
# Out:
# C:\Users\GIGABYTE\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
fixed_num.dtypes
# Out:
# price               float64
# weekly_price        float64
# monthly_price       float64
# security_deposit    float64
# cleaning_fee        float64
# extra_people        float64
# dtype: object

# %%
# will remove the col later, not usefull data
listing_df.smart_location.value_counts()
# Out:
# Seattle, WA                  3810
# West Seattle, WA                2
# Seattle , WA                    2
# Ballard, Seattle, WA            1
# seattle, wa                     1
# 西雅图, WA                         1
# Phinney Ridge Seattle, WA       1
# Name: smart_location, dtype: int64

# %%
numeric_df.shape
# Out:
# (3818, 28)

# %%
fixed_num.shape
# Out:
# (3818, 6)

# %% [markdown]
# <b>Lets concat the two numerical df together</b>

# %%
all_numeric_df = pd.concat([numeric_df, fixed_num], axis=1)

# %%
all_numeric_df.shape
# Out:
# (3818, 34)

# %%
all_numeric_df.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  3.818000e+03  3.818000e+03  3.818000e+03          3816.000000
# mean   5.550111e+06  2.016010e+13  1.578556e+07             7.157757
# std    2.962660e+06  0.000000e+00  1.458382e+07            28.628149
# min    3.335000e+03  2.016010e+13  4.193000e+03             1.000000
# 25%    3.258256e+06  2.016010e+13  3.275204e+06             1.000000
# 50%    6.118244e+06  2.016010e+13  1.055814e+07             1.000000
# 75%    8.035127e+06  2.016010e+13  2.590309e+07             3.000000
# max    1.034016e+07  2.016010e+13  5.320861e+07           502.000000
#
#        host_total_listings_count     latitude    longitude  accommodates  \
# count                3816.000000  3818.000000  3818.000000   3818.000000
# mean                    7.157757    47.628961  -122.333103      3.349398
# std                    28.628149     0.043052     0.031745      1.977599
# ...

# %%
all_numeric_df.isnull().sum()
# Out:
# id                                   0
# scrape_id                            0
# host_id                              0
# host_listings_count                  2
# host_total_listings_count            2
# latitude                             0
# longitude                            0
# accommodates                         0
# bathrooms                           16
# bedrooms                             6
# beds                                 1
# guests_included                      0
# minimum_nights                       0
# maximum_nights                       0
# availability_30                      0
# availability_60                      0
# availability_90                      0
# availability_365                     0
# number_of_reviews                    0
# review_scores_rating               647
# review_scores_accuracy             658
# review_scores_cleanliness          653
# review_scores_checkin              658
# review_scores_communication        651
# ...

# %%
all_numeric_df.isnull().sum() / all_numeric_df.shape[0]
# Out:
# id                                0.000000
# scrape_id                         0.000000
# host_id                           0.000000
# host_listings_count               0.000524
# host_total_listings_count         0.000524
# latitude                          0.000000
# longitude                         0.000000
# accommodates                      0.000000
# bathrooms                         0.004191
# bedrooms                          0.001572
# beds                              0.000262
# guests_included                   0.000000
# minimum_nights                    0.000000
# maximum_nights                    0.000000
# availability_30                   0.000000
# availability_60                   0.000000
# availability_90                   0.000000
# availability_365                  0.000000
# number_of_reviews                 0.000000
# review_scores_rating              0.169460
# review_scores_accuracy            0.172342
# review_scores_cleanliness         0.171032
# ...

# %%
#droped monthly_price col, almost 90% nans
all_numeric_df.drop('monthly_price', axis=1, inplace=True)

# %%
all_numeric_df.shape
# Out:
# (3818, 33)

# %%
all_numeric_df.head()
# Out:
#         id       scrape_id   host_id  host_listings_count  \
# 0   241032  20160104002432    956883                  3.0
# 1   953595  20160104002432   5177328                  6.0
# 2  3308979  20160104002432  16708587                  2.0
# 3  7421966  20160104002432   9851441                  1.0
# 4   278830  20160104002432   1452570                  2.0
#
#    host_total_listings_count   latitude   longitude  accommodates  bathrooms  \
# 0                        3.0  47.636289 -122.371025             4        1.0
# 1                        6.0  47.639123 -122.365666             4        1.0
# 2                        2.0  47.629724 -122.369483            11        4.5
# 3                        1.0  47.638473 -122.369279             3        1.0
# 4                        2.0  47.632918 -122.372471             6        2.0
#
#    bedrooms  beds  guests_included  minimum_nights  maximum_nights  \
# 0       1.0   1.0                2               1             365
# ...

# %%
listing_df.head(2)
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0  241032  https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1  953595  https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
#
#                                  name  \
# 0        Stylish Queen Anne Apartment
# 1  Bright & Airy Queen Anne Apartment
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
#
#                                                space  \
# 0  Make your self at home in this charming one-be...
# 1  Beautiful, hypoallergenic apartment in an extr...
#
#                                          description experiences_offered  \
# 0  Make your self at home in this charming one-be...                none
# 1  Chemically sensitive? We've removed the irrita...                none
#
#                                neighborhood_overview  \
# ...

# %%
listing_df.head(1)
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0  241032  https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
#
#                            name summary  \
# 0  Stylish Queen Anne Apartment     NaN
#
#                                                space  \
# 0  Make your self at home in this charming one-be...
#
#                                          description experiences_offered  \
# 0  Make your self at home in this charming one-be...                none
#
#   neighborhood_overview notes transit thumbnail_url medium_url  \
# 0                   NaN   NaN     NaN           NaN        NaN
#
#                                          picture_url xl_picture_url  host_id  \
# 0  https://a1.muscache.com/ac/pictures/67560560/c...            NaN   956883
#
#                                    host_url host_name  host_since  \
# 0  https://www.airbnb.com/users/show/956883     Maija  2011-08-11
#
# ...

# %%
#checked to see what cols are in listing_df and not in all_numeric
yes_list = []
no_list = []
for col in listing_df.columns:
    if col in all_numeric_df.columns:
        yes_list.append(col)
    else:
        no_list.append(col)

# %%
#below are the cols to be droped, so no duplicates
yes_list
# Out:
# ['id',
#  'scrape_id',
#  'host_id',
#  'host_listings_count',
#  'host_total_listings_count',
#  'latitude',
#  'longitude',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'price',
#  'weekly_price',
#  'security_deposit',
#  'cleaning_fee',
#  'guests_included',
#  'extra_people',
#  'minimum_nights',
#  'maximum_nights',
#  'availability_30',
#  'availability_60',
#  'availability_90',
#  'availability_365',
#  'number_of_reviews',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'calculated_host_listings_count',
#  'reviews_per_month']

# %%
droped_listing = listing_df.drop(yes_list, axis=1)

# %%
droped_listing.shape
# Out:
# (3818, 59)

# %%
listing_df.shape
# Out:
# (3818, 92)

# %%
for_seabon_all = pd.concat([droped_listing, all_numeric_df], axis=1)

# %%
for_seabon_all.columns
# Out:
# Index(['listing_url', 'last_scraped', 'name', 'summary', 'space',
#        'description', 'experiences_offered', 'neighborhood_overview', 'notes',
#        'transit', 'thumbnail_url', 'medium_url', 'picture_url',
#        'xl_picture_url', 'host_url', 'host_name', 'host_since',
#        'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'street', 'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'is_location_exact',
#        'property_type', 'room_type', 'bed_type', 'amenities', 'square_feet',
#        'monthly_price', 'calendar_updated', 'has_availability',
#        'calendar_last_scraped', 'first_review', 'last_review',
# ...

# %%
for_seabon_all.dtypes
# Out:
# listing_url                        object
# last_scraped                       object
# name                               object
# summary                            object
# space                              object
# description                        object
# experiences_offered                object
# neighborhood_overview              object
# notes                              object
# transit                            object
# thumbnail_url                      object
# medium_url                         object
# picture_url                        object
# xl_picture_url                     object
# host_url                           object
# host_name                          object
# host_since                         object
# host_location                      object
# host_about                         object
# host_response_time                 object
# host_response_rate                 object
# host_acceptance_rate               object
# ...

# %%
for_seabon_all.head(2)
# Out:
#                            listing_url last_scraped  \
# 0  https://www.airbnb.com/rooms/241032   2016-01-04
# 1  https://www.airbnb.com/rooms/953595   2016-01-04
#
#                                  name  \
# 0        Stylish Queen Anne Apartment
# 1  Bright & Airy Queen Anne Apartment
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
#
#                                                space  \
# 0  Make your self at home in this charming one-be...
# 1  Beautiful, hypoallergenic apartment in an extr...
#
#                                          description experiences_offered  \
# 0  Make your self at home in this charming one-be...                none
# 1  Chemically sensitive? We've removed the irrita...                none
#
#                                neighborhood_overview  \
# 0                                                NaN
# ...

# %%
for_seabon_all.shape
# Out:
# (3818, 92)

# %% [markdown]
# Will create a DF to see all the unique types of the categorical variables, this will help in choosing them later

# %%
from_cat = {}
for col in for_seabon_all.columns:
    if for_seabon_all[col].dtype == 'object':
        from_cat[col] = for_seabon_all[col].unique()
        #print('this is the col name {}'.format(col))
        #print(len(for_seabon_all[col].unique()))

# %%
cats = pd.DataFrame(dict([(k, pd.Series(v)) for k,v in from_cat.items() ]))
cats.head(2)
# Out:
#                            listing_url last_scraped  \
# 0  https://www.airbnb.com/rooms/241032   2016-01-04
# 1  https://www.airbnb.com/rooms/953595          NaN
#
#                                  name  \
# 0        Stylish Queen Anne Apartment
# 1  Bright & Airy Queen Anne Apartment
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
#
#                                                space  \
# 0  Make your self at home in this charming one-be...
# 1  Beautiful, hypoallergenic apartment in an extr...
#
#                                          description experiences_offered  \
# 0  Make your self at home in this charming one-be...                none
# 1  Chemically sensitive? We've removed the irrita...                 NaN
#
#                                neighborhood_overview  \
# 0                                                NaN
# ...

# %%
cats_counts = cats.notnull().sum()

# %% [markdown]
# Here i will choose the categorical variables that i will keep and which to discard due to the large number of different unique elements used.

# %%
cats_counts
# Out:
# listing_url                         3818
# last_scraped                           1
# name                                3792
# summary                             3478
# space                               3119
# description                         3742
# experiences_offered                    1
# neighborhood_overview               2506
# notes                               1999
# transit                             2574
# thumbnail_url                       3498
# medium_url                          3498
# picture_url                         3818
# xl_picture_url                      3498
# host_url                            2751
# host_name                           1466
# host_since                          1380
# host_location                        120
# host_about                          2011
# host_response_time                     4
# host_response_rate                    45
# host_acceptance_rate                   2
# host_is_superhost                      2
# ...

# %% [markdown]
# 17 is the number of unique variables that i will keep for the analyses

# %%
cat_list_to_keep = cats_counts[cats_counts <=17].index
cat_list_to_keep = cat_list_to_keep.values

# %%
cat_list_to_keep
# Out:
# array(['last_scraped', 'experiences_offered', 'host_response_time',
#        'host_acceptance_rate', 'host_is_superhost', 'host_has_profile_pic',
#        'host_identity_verified', 'neighbourhood_group_cleansed', 'city',
#        'state', 'market', 'smart_location', 'country_code', 'country',
#        'is_location_exact', 'property_type', 'room_type', 'bed_type',
#        'has_availability', 'calendar_last_scraped', 'requires_license',
#        'jurisdiction_names', 'instant_bookable', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification'], dtype=object)

# %% [markdown]
# Out of the 57 categorical cols, i decided to keep i only 26.

# %%
len(cats_counts)
# Out:
# 57

# %%
len(cat_list_to_keep)
# Out:
# 26

# %%
for_seabon_all[cat_list_to_keep].isnull().sum()
# Out:
# last_scraped                          0
# experiences_offered                   0
# host_response_time                  523
# host_acceptance_rate                773
# host_is_superhost                     2
# host_has_profile_pic                  2
# host_identity_verified                2
# neighbourhood_group_cleansed          0
# city                                  0
# state                                 0
# market                                0
# smart_location                        0
# country_code                          0
# country                               0
# is_location_exact                     0
# property_type                         1
# room_type                             0
# bed_type                              0
# has_availability                      0
# calendar_last_scraped                 0
# requires_license                      0
# jurisdiction_names                    0
# instant_bookable                      0
# ...

# %%
for_ML_cat = for_seabon_all[cat_list_to_keep]
for_ML_cat.head()
# Out:
#   last_scraped experiences_offered  host_response_time host_acceptance_rate  \
# 0   2016-01-04                none  within a few hours                 100%
# 1   2016-01-04                none      within an hour                 100%
# 2   2016-01-04                none  within a few hours                 100%
# 3   2016-01-04                none                 NaN                  NaN
# 4   2016-01-04                none      within an hour                  NaN
#
#   host_is_superhost host_has_profile_pic host_identity_verified  \
# 0                 f                    t                      t
# 1                 t                    t                      t
# 2                 f                    t                      t
# 3                 f                    t                      t
# 4                 f                    t                      t
#
#   neighbourhood_group_cleansed     city state   market smart_location  \
# ...

# %%
all_numeric_df.isnull().sum()
# Out:
# id                                   0
# scrape_id                            0
# host_id                              0
# host_listings_count                  2
# host_total_listings_count            2
# latitude                             0
# longitude                            0
# accommodates                         0
# bathrooms                           16
# bedrooms                             6
# beds                                 1
# guests_included                      0
# minimum_nights                       0
# maximum_nights                       0
# availability_30                      0
# availability_60                      0
# availability_90                      0
# availability_365                     0
# number_of_reviews                    0
# review_scores_rating               647
# review_scores_accuracy             658
# review_scores_cleanliness          653
# review_scores_checkin              658
# review_scores_communication        651
# ...

# %% [markdown]
# Decided to drop 3 cols in the numeric DF that are high in Nans

# %%
all_numeric_df_new = all_numeric_df.drop(['weekly_price', 'security_deposit', 'cleaning_fee'], axis=1)

# %%
all_numeric_df_new.isnull().sum()
# Out:
# id                                  0
# scrape_id                           0
# host_id                             0
# host_listings_count                 2
# host_total_listings_count           2
# latitude                            0
# longitude                           0
# accommodates                        0
# bathrooms                          16
# bedrooms                            6
# beds                                1
# guests_included                     0
# minimum_nights                      0
# maximum_nights                      0
# availability_30                     0
# availability_60                     0
# availability_90                     0
# availability_365                    0
# number_of_reviews                   0
# review_scores_rating              647
# review_scores_accuracy            658
# review_scores_cleanliness         653
# review_scores_checkin             658
# review_scores_communication       651
# review_scores_location            655
# ...

# %% [markdown]
# Now we will fill the nans with the mean of the col

# %%
all_numeric_df_new.fillna(all_numeric_df_new.mean(), inplace=True)

# %%
all_numeric_df_new.isnull().sum()
# Out:
# id                                0
# scrape_id                         0
# host_id                           0
# host_listings_count               0
# host_total_listings_count         0
# latitude                          0
# longitude                         0
# accommodates                      0
# bathrooms                         0
# bedrooms                          0
# beds                              0
# guests_included                   0
# minimum_nights                    0
# maximum_nights                    0
# availability_30                   0
# availability_60                   0
# availability_90                   0
# availability_365                  0
# number_of_reviews                 0
# review_scores_rating              0
# review_scores_accuracy            0
# review_scores_cleanliness         0
# review_scores_checkin             0
# review_scores_communication       0
# review_scores_location            0
# review_scores_value               0
# ...

# %% [markdown]
# <b> Concat the two Data Frames, the Categolical and Numeric</b>

# %%
ml_combined = pd.concat([for_ML_cat, all_numeric_df_new], axis=1)

# %%
ml_combined.head()
# Out:
#   last_scraped experiences_offered  host_response_time host_acceptance_rate  \
# 0   2016-01-04                none  within a few hours                 100%
# 1   2016-01-04                none      within an hour                 100%
# 2   2016-01-04                none  within a few hours                 100%
# 3   2016-01-04                none                 NaN                  NaN
# 4   2016-01-04                none      within an hour                  NaN
#
#   host_is_superhost host_has_profile_pic host_identity_verified  \
# 0                 f                    t                      t
# 1                 t                    t                      t
# 2                 f                    t                      t
# 3                 f                    t                      t
# 4                 f                    t                      t
#
#   neighbourhood_group_cleansed     city state   market smart_location  \
# ...

# %%
ml_combined.shape
# Out:
# (3818, 56)

# %%
ml_combined.isnull().sum()
# Out:
# last_scraped                          0
# experiences_offered                   0
# host_response_time                  523
# host_acceptance_rate                773
# host_is_superhost                     2
# host_has_profile_pic                  2
# host_identity_verified                2
# neighbourhood_group_cleansed          0
# city                                  0
# state                                 0
# market                                0
# smart_location                        0
# country_code                          0
# country                               0
# is_location_exact                     0
# property_type                         1
# room_type                             0
# bed_type                              0
# has_availability                      0
# calendar_last_scraped                 0
# requires_license                      0
# jurisdiction_names                    0
# instant_bookable                      0
# ...

# %%
ml_combined.shape
# Out:
# (3818, 59)

# %%
ml_combined.dropna(how='any', axis=0, inplace=True)

# %%
ml_combined.shape
# Out:
# (3026, 56)

# %%
ml_combined.to_csv(r'C:/Users/Qdashti/Desktop/qaiss_files_new/blog_post/ml_combined.csv')

# %% [markdown]
# <h2> Visual Analyses of the Data Frame </h2>
#
# At this stage, we will explore the data using Seaborn and see if we can find some usefull insights

# %%
for_seabon_all['host_has_profile_pic'] = for_seabon_all.host_has_profile_pic.map(dict(t=1, f=0))

# %%
for_seabon_all.host_has_profile_pic.unique()
# Out:
# array(['t', 'f', nan], dtype=object)

# %%
for_seabon_all.host_identity_verified.unique()
# Out:
# array(['t', 'f', nan], dtype=object)

# %%
sns.relplot(data=for_seabon_all, x='review_scores_rating', y='price', hue='host_has_profile_pic')

# %%
plt.figure(figsize=(15,12))
sns.relplot(data=for_seabon_all, x='reviews_per_month', y='price', hue='host_has_profile_pic', size='accommodates',
           sizes=(10, 125), alpha=0.75,palette="YlGnBu")
#this could be an interesing inverted assumpation, that the less the property is rated the higher he can charged

# %%
sns.scatterplot(data=for_seabon_all, y='price', x='availability_30')

# %%
sns.scatterplot(data=for_seabon_all, y='price', x='availability_60')

# %%
sns.scatterplot(data=for_seabon_all, y='price', x='availability_90')

# %%
sns.relplot(data=for_seabon_all, x='reviews_per_month', y='price', hue='property_type', size='accommodates',
           sizes=(10, 125))

# %%
sns.relplot(data=for_seabon_all, x='number_of_reviews', y='price', hue='property_type', size='accommodates',
           sizes=(10, 125))
plt.axvline(for_seabon_all.number_of_reviews.mean(), color='b', linestyle='dashed', linewidth=1)

# %%
for_seabon_all.describe()
# Out:
#        square_feet  license            id     scrape_id       host_id  \
# count    97.000000      0.0  3.818000e+03  3.818000e+03  3.818000e+03
# mean    854.618557      NaN  5.550111e+06  2.016010e+13  1.578556e+07
# std     671.404893      NaN  2.962660e+06  0.000000e+00  1.458382e+07
# min       0.000000      NaN  3.335000e+03  2.016010e+13  4.193000e+03
# 25%     420.000000      NaN  3.258256e+06  2.016010e+13  3.275204e+06
# 50%     750.000000      NaN  6.118244e+06  2.016010e+13  1.055814e+07
# 75%    1200.000000      NaN  8.035127e+06  2.016010e+13  2.590309e+07
# max    3000.000000      NaN  1.034016e+07  2.016010e+13  5.320861e+07
#
#        host_listings_count  host_total_listings_count     latitude  \
# count          3816.000000                3816.000000  3818.000000
# mean              7.157757                   7.157757    47.628961
# std              28.628149                  28.628149     0.043052
# ...

# %%
plt.figure(figsize=(15,15))
sns.relplot(data=for_seabon_all, x='review_scores_rating', y='price', size='accommodates', hue='property_type')
plt.axhline(for_seabon_all.price.mean(), color='b', linestyle='dashed', linewidth=1)
plt.axhline((for_seabon_all.price.mean() + for_seabon_all.price.std()), color='k', linestyle='dashed', linewidth=1)
plt.axhline((for_seabon_all.price.mean() - for_seabon_all.price.std()) , color='k', linestyle='dashed', linewidth=1)
#plt.legend()

# %%
sns.relplot(data=for_seabon_all, x='reviews_per_month', y='price', hue='room_type')

# %%
sns.relplot(data=for_seabon_all, x='reviews_per_month', y='price',  hue='cancellation_policy')

# %%
sns.countplot(for_seabon_all.cancellation_policy)

# %%
sns.boxplot(data=for_seabon_all, x='neighbourhood_group_cleansed', y='price')

# %%
plt.figure(figsize=(10,5))
chart = sns.boxplot(data=for_seabon_all, x='neighbourhood_group_cleansed', y='price')
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, fontsize='large', horizontalalignment='right');

# %%
plt.figure(figsize=(10,5))
chart = sns.boxplot(data=for_seabon_all, x='property_type', y='price')
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, fontsize='large', horizontalalignment='right');

# %%
neigh_price_df = for_seabon_all[['neighbourhood_group_cleansed', 'price']].groupby('neighbourhood_group_cleansed').mean().sort_values(by='price', ascending=False)
neigh_price_df
# Out:
#                                    price
# neighbourhood_group_cleansed
# Magnolia                      177.672131
# Queen Anne                    157.223729
# Downtown                      154.405660
# West Seattle                  141.359606
# Cascade                       140.101124
# Capitol Hill                  130.592593
# Central Area                  128.338753
# Ballard                       124.682609
# Other neighborhoods           118.858764
# Interbay                      109.727273
# Seward Park                   108.477273
# Beacon Hill                    94.669492
# University District            93.639344
# Lake City                      92.671642
# Rainier Valley                 91.899371
# Northgate                      88.550000
# Delridge                       83.278481

# %%
#sns.distplot(for_seabon_all.accommodates)
test_rating = for_seabon_all.review_scores_rating.dropna()
#sns.distplot(for_seabon_all.review_scores_rating)

sns.distplot(test_rating)
plt.axvline(test_rating.mean(), linestyle='dashed')
print(test_rating.mean())
# Out:
# 94.53926206244087

# %%
price_droped = for_seabon_all.price.dropna()

sns.distplot(price_droped)
std_plus = price_droped.mean() + price_droped.std()
std_minus = price_droped.mean() - price_droped.std()
plt.axvline(price_droped.mean(), linestyle='dashed', label='mean at 127 USD')
plt.axvline(std_minus, color='k', label='one std above')
plt.axvline(std_plus, color='k', label='one std below')
plt.legend()
print(std_minus)
print(std_plus)
# Out:
# 38.596847856281855
# 216.89856739129476

# %%
chart = sns.catplot(data=for_seabon_all, x='neighbourhood_group_cleansed', kind='count')
chart.set_xticklabels(rotation=45, fontsize='large', horizontalalignment='right')

# %%
plt.figure(figsize=(10,5))
chart = sns.catplot(data=for_seabon_all, x='property_type', y='price')
chart.set_xticklabels(rotation=45, fontsize='large', horizontalalignment='right');

# %%
chart = sns.catplot(data=for_seabon_all, x='property_type', kind='count')
chart.set_xticklabels(rotation=45, fontsize='large', horizontalalignment='right')

# %%
plt.figure(figsize=(15,15))
chart = sns.catplot(data=for_seabon_all, x='neighbourhood_group_cleansed', kind='count', hue='cancellation_policy')
chart.set_xticklabels(rotation=45, fontsize='large', horizontalalignment='right')

# %%
listing_df.property_type.value_counts()  / listing_df.property_type.value_counts().sum()
# Out:
# House              0.454021
# Apartment          0.447472
# Townhouse          0.030914
# Condominium        0.023841
# Loft               0.010479
# Bed & Breakfast    0.009693
# Other              0.005764
# Cabin              0.005502
# Bungalow           0.003406
# Camper/RV          0.003406
# Boat               0.002096
# Tent               0.001310
# Treehouse          0.000786
# Dorm               0.000524
# Chalet             0.000524
# Yurt               0.000262
# Name: property_type, dtype: float64
